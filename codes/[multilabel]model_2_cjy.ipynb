# %% [markdown]
# ## Multi Label Classification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import datetime
import os
from tensorflow.keras.layers import Input, Dense, concatenate
from tensorflow.keras.models import Model
import pandas as pd 
import numpy as np
import tensorflow as tf
import datetime
import os
from tensorflow.keras.layers import Input, Dense, concatenate, BatchNormalization
from tensorflow.keras.models import Model
import pandas as pd 
import numpy as np
from sklearn.preprocessing import MinMaxScaler


from keras import metrics

# %%
## load input data

pad_x = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/second_pad_x.npy')
student_major = pd.read_csv('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/new_student_major.csv')
y = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/second_train_y.npy')

print("pad_x shape : ", pad_x.shape)
print("major shape : ", student_major.shape)
print("y shape : ", y.shape)
# Out:
# pad_x shape :  (21966, 84)
# major shape :  (21966, 2)
# y shape :  (21966, 133878)

# %%
## load embeddings

#image_embedding
image_embeddings = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/image_embedding.npy')
image_embeddings= np.reshape(image_embeddings, (133878, 1280))
min_max_scaler = MinMaxScaler()
image_embeddings = min_max_scaler.fit_transform(image_embeddings)
print("image embedding : ", image_embeddings.shape) #(133878, 1280)

#page-year embedding
page_embeddings = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/page_embeddings.npy')
min_max_scaler = MinMaxScaler()
page_embeddings = min_max_scaler.fit_transform(page_embeddings)
print("page embedding : ", page_embeddings.shape) #(133878, 6)


#BERT genre embedding 
genre_embeddings = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/genre_embeddings(word).npy')
min_max_scaler = MinMaxScaler()
genre_embeddings = min_max_scaler.fit_transform(genre_embeddings)
print("genre embedding : ", genre_embeddings.shape) #(133878, 768)


#bert title embedding 
title_embeddings = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/sentence_embeddings.npy')
min_max_scaler = MinMaxScaler()
title_embeddings = min_max_scaler.fit_transform(title_embeddings)
print("title embedding : ", title_embeddings.shape) #(133878, 768)

#bert MAJOR embedding 
major_embeddings = np.load('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/major_embeddings.npy') #major_embeddings_full_name(with college).npy
min_max_scaler = MinMaxScaler()
major_embeddings = min_max_scaler.fit_transform(major_embeddings)
print("major_embedding : ", major_embeddings.shape) #(22024, 768)
# Out:
# image embedding :  (133878, 1280)
# page embedding :  (133878, 6)
# genre embedding :  (133878, 768)
# title embedding :  (133878, 768)
# major_embedding :  (21966, 768)

# %%
# from keras.metrics import top_k_categorical_accuracy

# def top_5_categorical_accuracy(y_true, y_pred):
#     return top_k_categorical_accuracy(y_true, y_pred, k=5)

# %%
# 랜덤시드 고정시키기
np.random.seed(2021)
tf.random.set_seed(2021)

#basic settings 
LEARNING_RATE = 0.01
DROPOUT_PCT = 0.5
ALPHA = 0.1

student_num = pad_x.shape[0]
book_num = title_embeddings.shape[0]


#INPUT 
max_len = 84
book = tf.keras.Input(shape=(max_len, ), name='book-table') #shape: user,book
user = tf.keras.Input(shape=(1, ), name='user-table') #shape: user,book


#EMBEDDING 
#title 
text_embedding_layer = tf.keras.layers.Embedding(input_dim = title_embeddings.shape[0] ,  #133878
                                                 output_dim = title_embeddings.shape[1], #768,
                                                 input_length = max_len, 
                                                #  mask_zero = True,
                                                 weights = [title_embeddings],
                                                 trainable=True, 
                                                 name = 'RoBERT-book-text-embedding')


#book image 
img_embedding_layer = tf.keras.layers.Embedding(input_dim = image_embeddings.shape[0] ,   #133878
                                                output_dim = image_embeddings.shape[1], #1028,
                                                input_length = max_len, 
                                                # mask_zero = True,
                                                weights = [image_embeddings],
                                                trainable=True, 
                                                name = 'efficientNet-book-image-embedding')


#genre 
book_genre_embeddings = tf.keras.layers.Embedding(input_dim = genre_embeddings.shape[0] , 
                                                  output_dim = genre_embeddings.shape[1], 
                                                  input_length = max_len, 
                                                  # mask_zero = True,
                                                  weights = [genre_embeddings],
                                                  trainable=True, 
                                                  name = 'RoBERT-book-genre-embedding')


#LOOK-UP TABLE 
#book_age(pub year) &  page 
book_info_embeddings = tf.keras.layers.Embedding(input_dim = page_embeddings.shape[0] , 
                                                 output_dim = page_embeddings.shape[1], 
                                                 input_length = max_len, 
                                                #  mask_zero = True,
                                                 weights = [page_embeddings],
                                                 trainable=True, 
                                                 name = 'book-info-embedding')

#major 
user_info_layer = tf.keras.layers.Embedding(input_dim = major_embeddings.shape[0] ,  #22024
                                            output_dim = major_embeddings.shape[1],  #768
                                            input_length = 1, 
                                            # mask_zero = True,
                                            weights = [major_embeddings],
                                            trainable=True, 
                                            name = 'RoBERT-user-major-embedding')



#DENSE LAYER 
dense_1 = tf.keras.layers.Dense(units = 1024, activation = 'relu', name = 'dense_1',kernel_initializer = 'he_uniform')
dense_2 = tf.keras.layers.Dense(units = 2048, activation = 'tanh', name = 'dense_2',kernel_initializer = 'he_uniform')

dense_output = tf.keras.layers.Dense(page_embeddings.shape[0], activation = 'sigmoid', name = 'sigmoid_output')
dropout_1= tf.keras.layers.Dropout(DROPOUT_PCT, name = 'dropout1')


#EMBEDDINGS 
text_embeddings = text_embedding_layer(book)
title= tf.keras.layers.GlobalAveragePooling1D(name = 'AveragePooling_embedding1')(text_embeddings)

img_embeddings = img_embedding_layer(book)
image = tf.keras.layers.GlobalAveragePooling1D(name = 'AveragePooling_embedding2')(img_embeddings)

genre_embeddings = book_genre_embeddings(book)
genre= tf.keras.layers.GlobalAveragePooling1D(name = 'AveragePooling_embedding3')(genre_embeddings)

info_embeddings = book_info_embeddings(book)
info= tf.keras.layers.GlobalAveragePooling1D(name = 'AveragePooling_embedding4')(info_embeddings)

user_info_embeddings = user_info_layer(user)
major= tf.keras.layers.GlobalAveragePooling1D(name = 'AveragePooling_embedding5')(user_info_embeddings)



#BUILD MODEL 

#CONCAT : title, genre, major
concat_inputs = tf.keras.layers.Concatenate(axis = 1, name = 'concat-inputs')([image, info, title, genre, major])
concat_inputs = tf.keras.layers.BatchNormalization(name = 'concat_batch_norm')(concat_inputs)


#DENSE 
dense_1_features = dense_1(concat_inputs)
dense_1_batch_norm = tf.keras.layers.BatchNormalization(name='dense_1_batch_norm')(dense_1_features)
dense_1_relu = dense_1_batch_norm

dense_2_features = dense_2(dense_1_relu)
dense_2_relu = dense_2_features
dense_2_dropout = dropout_1(dense_2_relu)

outputs = dense_output(dense_2_dropout)



#Optimizer
# optimizer = tf.keras.optimizers.AdaGrad(learning_rate = LEARNING_RATE)
# optimizer= tf.keras.optimizers.SGD(learning_rate = LEARNING_RATE, name='SGD')
# optimizer= tf.keras.optimizers.SGD(learning_rate = LEARNING_RATE, momentum = 0.8, name = 'SGD')

# optimizer= tf.keras.optimizers.Adam(learning_rate = LEARNING_RATE, name = 'adam')
optimizer= tf.keras.optimizers.RMSprop(learning_rate= LEARNING_RATE , name = 'RMSprop')


model = tf.keras.models.Model(inputs = [book, user], outputs = [outputs])



model.compile(optimizer = optimizer,
              loss = tf.keras.losses.BinaryCrossentropy(), # loss = tf.nn.weighted_cross_entropy_with_logits( 'labels', 'logits',  'pos_weight'),
              metrics = ['categorical_accuracy']) #tf.keras.metrics.top_k_categorical_accuracy() top__categorical_accuracy



# VISUALIZATION 
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True,dpi=96)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# book-table (InputLayer)         [(None, 84)]         0
# __________________________________________________________________________________________________
# user-table (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# efficientNet-book-image-embeddi (None, 84, 1280)     171363840   book-table[0][0]
# __________________________________________________________________________________________________
# book-info-embedding (Embedding) (None, 84, 6)        803268      book-table[0][0]
# __________________________________________________________________________________________________
# RoBERT-book-text-embedding (Emb (None, 84, 768)      102818304   book-table[0][0]
# __________________________________________________________________________________________________
# RoBERT-book-genre-embedding (Em (None, 84, 768)      102818304   book-table[0][0]
# __________________________________________________________________________________________________
# RoBERT-user-major-embedding (Em (None, 1, 768)       16869888    user-table[0][0]
# __________________________________________________________________________________________________
# AveragePooling_embedding2 (Glob (None, 1280)         0           efficientNet-book-image-embedding
# __________________________________________________________________________________________________
# AveragePooling_embedding4 (Glob (None, 6)            0           book-info-embedding[0][0]
# __________________________________________________________________________________________________
# AveragePooling_embedding1 (Glob (None, 768)          0           RoBERT-book-text-embedding[0][0]
# __________________________________________________________________________________________________
# AveragePooling_embedding3 (Glob (None, 768)          0           RoBERT-book-genre-embedding[0][0]
# __________________________________________________________________________________________________
# AveragePooling_embedding5 (Glob (None, 768)          0           RoBERT-user-major-embedding[0][0]
# __________________________________________________________________________________________________
# concat-inputs (Concatenate)     (None, 3590)         0           AveragePooling_embedding2[0][0]
#                                                                  AveragePooling_embedding4[0][0]
#                                                                  AveragePooling_embedding1[0][0]
#                                                                  AveragePooling_embedding3[0][0]
#                                                                  AveragePooling_embedding5[0][0]
# __________________________________________________________________________________________________
# concat_batch_norm (BatchNormali (None, 3590)         14360       concat-inputs[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         3677184     concat_batch_norm[0][0]
# __________________________________________________________________________________________________
# dense_1_batch_norm (BatchNormal (None, 1024)         4096        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2048)         2099200     dense_1_batch_norm[0][0]
# __________________________________________________________________________________________________
# dropout1 (Dropout)              (None, 2048)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# sigmoid_output (Dense)          (None, 133878)       274316022   dropout1[0][0]
# ==================================================================================================
# Total params: 674,784,466
# Trainable params: 674,775,238
# Non-trainable params: 9,228
# __________________________________________________________________________________________________

# %%
history = model.fit([pad_x, student_major['major']], y, epochs = 250, batch_size = 64)
# Out:
# Epoch 1/250
# 344/344 [==============================] - 257s 737ms/step - loss: 0.5835 - categorical_accuracy: 5.2432e-04
# Epoch 2/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.8171e-04 - categorical_accuracy: 3.6034e-04
# Epoch 3/250
# 344/344 [==============================] - 251s 728ms/step - loss: 2.7741e-04 - categorical_accuracy: 3.8968e-04
# Epoch 4/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.5828e-04 - categorical_accuracy: 0.0011
# Epoch 5/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.6909e-04 - categorical_accuracy: 4.9384e-04
# Epoch 6/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.6169e-04 - categorical_accuracy: 5.8602e-04
# Epoch 7/250
# 344/344 [==============================] - 251s 728ms/step - loss: 2.7176e-04 - categorical_accuracy: 5.2525e-04
# Epoch 8/250
# 344/344 [==============================] - 256s 745ms/step - loss: 2.6963e-04 - categorical_accuracy: 8.4072e-04
# Epoch 9/250
# 344/344 [==============================] - 252s 733ms/step - loss: 4.3222e-04 - categorical_accuracy: 7.3874e-04
# Epoch 10/250
# 344/344 [==============================] - 252s 734ms/step - loss: 2.9315e-04 - categorical_accuracy: 3.8134e-04
# Epoch 11/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.5742e-04 - categorical_accuracy: 6.7663e-04
# Epoch 12/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.7642e-04 - categorical_accuracy: 0.0012
# Epoch 13/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.6115e-04 - categorical_accuracy: 7.9248e-04
# Epoch 14/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.5740e-04 - categorical_accuracy: 4.8627e-04
# Epoch 15/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.5719e-04 - categorical_accuracy: 9.2825e-04
# Epoch 16/250
# 344/344 [==============================] - 251s 728ms/step - loss: 2.5447e-04 - categorical_accuracy: 0.0015
# Epoch 17/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.5433e-04 - categorical_accuracy: 0.0018
# Epoch 18/250
# 344/344 [==============================] - 252s 731ms/step - loss: 2.6552e-04 - categorical_accuracy: 0.0019
# Epoch 19/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.4499e-04 - categorical_accuracy: 0.0015
# Epoch 20/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.4578e-04 - categorical_accuracy: 0.0015
# Epoch 21/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.4640e-04 - categorical_accuracy: 0.0018
# Epoch 22/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.6548e-04 - categorical_accuracy: 0.0014
# Epoch 23/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.5946e-04 - categorical_accuracy: 9.5973e-04
# Epoch 24/250
# 344/344 [==============================] - 252s 733ms/step - loss: 2.7759e-04 - categorical_accuracy: 0.0016
# Epoch 25/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.5689e-04 - categorical_accuracy: 0.0019
# Epoch 26/250
# 344/344 [==============================] - 252s 731ms/step - loss: 2.6105e-04 - categorical_accuracy: 0.0017
# Epoch 27/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.3874e-04 - categorical_accuracy: 0.0018
# Epoch 28/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.4653e-04 - categorical_accuracy: 0.0024
# Epoch 29/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.4933e-04 - categorical_accuracy: 0.0030
# Epoch 30/250
# 344/344 [==============================] - 252s 732ms/step - loss: 2.4861e-04 - categorical_accuracy: 0.0024
# Epoch 31/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.6484e-04 - categorical_accuracy: 0.0031
# Epoch 32/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.4794e-04 - categorical_accuracy: 0.0027
# Epoch 33/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.4929e-04 - categorical_accuracy: 0.0021
# Epoch 34/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.5344e-04 - categorical_accuracy: 0.0042
# Epoch 35/250
# 344/344 [==============================] - 251s 729ms/step - loss: 2.5229e-04 - categorical_accuracy: 0.0031
# Epoch 36/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.3434e-04 - categorical_accuracy: 0.0045
# Epoch 37/250
# 344/344 [==============================] - 251s 728ms/step - loss: 2.4085e-04 - categorical_accuracy: 0.0050
# Epoch 38/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.4405e-04 - categorical_accuracy: 0.0045
# Epoch 39/250
# 344/344 [==============================] - 252s 731ms/step - loss: 2.5495e-04 - categorical_accuracy: 0.0055
# Epoch 40/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.6795e-04 - categorical_accuracy: 0.0056
# Epoch 41/250
# 344/344 [==============================] - 251s 730ms/step - loss: 2.5972e-04 - categorical_accuracy: 0.0052
# Epoch 42/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.3715e-04 - categorical_accuracy: 0.0073
# Epoch 43/250
# 344/344 [==============================] - 249s 725ms/step - loss: 2.3951e-04 - categorical_accuracy: 0.0059
# Epoch 44/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.3992e-04 - categorical_accuracy: 0.0071
# Epoch 45/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.3707e-04 - categorical_accuracy: 0.0077
# Epoch 46/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.3722e-04 - categorical_accuracy: 0.0074
# Epoch 47/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.2814e-04 - categorical_accuracy: 0.0078
# Epoch 48/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.2989e-04 - categorical_accuracy: 0.0103
# Epoch 49/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.3258e-04 - categorical_accuracy: 0.0079
# Epoch 50/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.3378e-04 - categorical_accuracy: 0.0089
# Epoch 51/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.2287e-04 - categorical_accuracy: 0.0085
# Epoch 52/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.2418e-04 - categorical_accuracy: 0.0124
# Epoch 53/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.2951e-04 - categorical_accuracy: 0.0136
# Epoch 54/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.3589e-04 - categorical_accuracy: 0.0107
# Epoch 55/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.1629e-04 - categorical_accuracy: 0.0111
# Epoch 56/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.2342e-04 - categorical_accuracy: 0.0114
# Epoch 57/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.1975e-04 - categorical_accuracy: 0.0168
# Epoch 58/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.1306e-04 - categorical_accuracy: 0.0160
# Epoch 59/250
# 344/344 [==============================] - 249s 723ms/step - loss: 2.1617e-04 - categorical_accuracy: 0.0164
# Epoch 60/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.2228e-04 - categorical_accuracy: 0.0130
# Epoch 61/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.3752e-04 - categorical_accuracy: 0.0150
# Epoch 62/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.1176e-04 - categorical_accuracy: 0.0156
# Epoch 63/250
# 344/344 [==============================] - 250s 728ms/step - loss: 2.1277e-04 - categorical_accuracy: 0.0172
# Epoch 64/250
# 344/344 [==============================] - 250s 727ms/step - loss: 2.1345e-04 - categorical_accuracy: 0.0172
# Epoch 65/250
# 344/344 [==============================] - 250s 725ms/step - loss: 2.2139e-04 - categorical_accuracy: 0.0182
# Epoch 66/250
# 344/344 [==============================] - 250s 726ms/step - loss: 2.0605e-04 - categorical_accuracy: 0.0238
# Epoch 67/250
# 344/344 [==============================] - 251s 731ms/step - loss: 2.1851e-04 - categorical_accuracy: 0.0207
# Epoch 68/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.9921e-04 - categorical_accuracy: 0.0204
# Epoch 69/250
# 344/344 [==============================] - 250s 725ms/step - loss: 2.1531e-04 - categorical_accuracy: 0.0203
# Epoch 70/250
# 344/344 [==============================] - 249s 724ms/step - loss: 2.0025e-04 - categorical_accuracy: 0.0255
# Epoch 71/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.9770e-04 - categorical_accuracy: 0.0241
# Epoch 72/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.9641e-04 - categorical_accuracy: 0.0263
# Epoch 73/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.9293e-04 - categorical_accuracy: 0.0291
# Epoch 74/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.9219e-04 - categorical_accuracy: 0.0297
# Epoch 75/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.9902e-04 - categorical_accuracy: 0.0318
# Epoch 76/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.9444e-04 - categorical_accuracy: 0.0321
# Epoch 77/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.8939e-04 - categorical_accuracy: 0.0334
# Epoch 78/250
# 344/344 [==============================] - 248s 721ms/step - loss: 1.9226e-04 - categorical_accuracy: 0.0335
# Epoch 79/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.9636e-04 - categorical_accuracy: 0.0320
# Epoch 80/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.8810e-04 - categorical_accuracy: 0.0388
# Epoch 81/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.9286e-04 - categorical_accuracy: 0.0353
# Epoch 82/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.8979e-04 - categorical_accuracy: 0.0357
# Epoch 83/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.8546e-04 - categorical_accuracy: 0.0411
# Epoch 84/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.8248e-04 - categorical_accuracy: 0.0452
# Epoch 85/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.8279e-04 - categorical_accuracy: 0.0411
# Epoch 86/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.8840e-04 - categorical_accuracy: 0.0425
# Epoch 87/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.8734e-04 - categorical_accuracy: 0.0423
# Epoch 88/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.8223e-04 - categorical_accuracy: 0.0474
# Epoch 89/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.7224e-04 - categorical_accuracy: 0.0458
# Epoch 90/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.7229e-04 - categorical_accuracy: 0.0507
# Epoch 91/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.6966e-04 - categorical_accuracy: 0.0552
# Epoch 92/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.7242e-04 - categorical_accuracy: 0.0533
# Epoch 93/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.7820e-04 - categorical_accuracy: 0.0556
# Epoch 94/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.7536e-04 - categorical_accuracy: 0.0571
# Epoch 95/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.7649e-04 - categorical_accuracy: 0.0553
# Epoch 96/250
# 344/344 [==============================] - 250s 725ms/step - loss: 1.6484e-04 - categorical_accuracy: 0.0617
# Epoch 97/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.6132e-04 - categorical_accuracy: 0.0693
# Epoch 98/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.7674e-04 - categorical_accuracy: 0.0632
# Epoch 99/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.6953e-04 - categorical_accuracy: 0.0622
# Epoch 100/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.6033e-04 - categorical_accuracy: 0.0683
# Epoch 101/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.6672e-04 - categorical_accuracy: 0.0628
# Epoch 102/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.6030e-04 - categorical_accuracy: 0.0736
# Epoch 103/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.6460e-04 - categorical_accuracy: 0.0708
# Epoch 104/250
# 344/344 [==============================] - 249s 722ms/step - loss: 1.7088e-04 - categorical_accuracy: 0.0729
# Epoch 105/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.5787e-04 - categorical_accuracy: 0.0777
# Epoch 106/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.6173e-04 - categorical_accuracy: 0.0788
# Epoch 107/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.5563e-04 - categorical_accuracy: 0.0836
# Epoch 108/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.5458e-04 - categorical_accuracy: 0.0872
# Epoch 109/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.5856e-04 - categorical_accuracy: 0.0882
# Epoch 110/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.5221e-04 - categorical_accuracy: 0.0884
# Epoch 111/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.5567e-04 - categorical_accuracy: 0.0899
# Epoch 112/250
# 344/344 [==============================] - 249s 723ms/step - loss: 1.5306e-04 - categorical_accuracy: 0.0927
# Epoch 113/250
# 344/344 [==============================] - 250s 725ms/step - loss: 1.5331e-04 - categorical_accuracy: 0.0948
# Epoch 114/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.4962e-04 - categorical_accuracy: 0.0981
# Epoch 115/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.5175e-04 - categorical_accuracy: 0.0933
# Epoch 116/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.5474e-04 - categorical_accuracy: 0.0986
# Epoch 117/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.4682e-04 - categorical_accuracy: 0.1099
# Epoch 118/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.5013e-04 - categorical_accuracy: 0.1059
# Epoch 119/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.5380e-04 - categorical_accuracy: 0.1041
# Epoch 120/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.5206e-04 - categorical_accuracy: 0.1126
# Epoch 121/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.5131e-04 - categorical_accuracy: 0.1136
# Epoch 122/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.4489e-04 - categorical_accuracy: 0.1237
# Epoch 123/250
# 344/344 [==============================] - 252s 733ms/step - loss: 1.4149e-04 - categorical_accuracy: 0.1275
# Epoch 124/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.3938e-04 - categorical_accuracy: 0.1316
# Epoch 125/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.5847e-04 - categorical_accuracy: 0.1260
# Epoch 126/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.4489e-04 - categorical_accuracy: 0.1207
# Epoch 127/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.4236e-04 - categorical_accuracy: 0.1317
# Epoch 128/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.3701e-04 - categorical_accuracy: 0.1387
# Epoch 129/250
# 344/344 [==============================] - 252s 732ms/step - loss: 1.4070e-04 - categorical_accuracy: 0.1424
# Epoch 130/250
# 344/344 [==============================] - 251s 730ms/step - loss: 1.3956e-04 - categorical_accuracy: 0.1404
# Epoch 131/250
# 344/344 [==============================] - 251s 729ms/step - loss: 1.3753e-04 - categorical_accuracy: 0.1440
# Epoch 132/250
# 344/344 [==============================] - 251s 731ms/step - loss: 1.2902e-04 - categorical_accuracy: 0.1596
# Epoch 133/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.3625e-04 - categorical_accuracy: 0.1510
# Epoch 134/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.3616e-04 - categorical_accuracy: 0.1517
# Epoch 135/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.3539e-04 - categorical_accuracy: 0.1539
# Epoch 136/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.3526e-04 - categorical_accuracy: 0.1601
# Epoch 137/250
# 344/344 [==============================] - 251s 729ms/step - loss: 1.3242e-04 - categorical_accuracy: 0.1723
# Epoch 138/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.4030e-04 - categorical_accuracy: 0.1622
# Epoch 139/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.3027e-04 - categorical_accuracy: 0.1721
# Epoch 140/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.2927e-04 - categorical_accuracy: 0.1801
# Epoch 141/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.2462e-04 - categorical_accuracy: 0.1855
# Epoch 142/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.3312e-04 - categorical_accuracy: 0.1771
# Epoch 143/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.2682e-04 - categorical_accuracy: 0.1980
# Epoch 144/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.3275e-04 - categorical_accuracy: 0.1781
# Epoch 145/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.2971e-04 - categorical_accuracy: 0.1935
# Epoch 146/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.2910e-04 - categorical_accuracy: 0.1893
# Epoch 147/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.2480e-04 - categorical_accuracy: 0.2055
# Epoch 148/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.2532e-04 - categorical_accuracy: 0.2032
# Epoch 149/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.1989e-04 - categorical_accuracy: 0.2075
# Epoch 150/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.2649e-04 - categorical_accuracy: 0.2035
# Epoch 151/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.2231e-04 - categorical_accuracy: 0.2161
# Epoch 152/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.2425e-04 - categorical_accuracy: 0.2121
# Epoch 153/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.2071e-04 - categorical_accuracy: 0.2209
# Epoch 154/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.2252e-04 - categorical_accuracy: 0.2111
# Epoch 155/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.2175e-04 - categorical_accuracy: 0.2204
# Epoch 156/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.2168e-04 - categorical_accuracy: 0.2171
# Epoch 157/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.1643e-04 - categorical_accuracy: 0.2354
# Epoch 158/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.2036e-04 - categorical_accuracy: 0.2408
# Epoch 159/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.1886e-04 - categorical_accuracy: 0.2405
# Epoch 160/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.1444e-04 - categorical_accuracy: 0.2470
# Epoch 161/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.2049e-04 - categorical_accuracy: 0.2333
# Epoch 162/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.1805e-04 - categorical_accuracy: 0.2399
# Epoch 163/250
# 344/344 [==============================] - 250s 725ms/step - loss: 1.1421e-04 - categorical_accuracy: 0.2609
# Epoch 164/250
# 344/344 [==============================] - 250s 725ms/step - loss: 1.1309e-04 - categorical_accuracy: 0.2655
# Epoch 165/250
# 344/344 [==============================] - 250s 725ms/step - loss: 1.1327e-04 - categorical_accuracy: 0.2569
# Epoch 166/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.1207e-04 - categorical_accuracy: 0.2592
# Epoch 167/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.1360e-04 - categorical_accuracy: 0.2685
# Epoch 168/250
# 344/344 [==============================] - 251s 729ms/step - loss: 1.1131e-04 - categorical_accuracy: 0.2721
# Epoch 169/250
# 344/344 [==============================] - 251s 728ms/step - loss: 1.1191e-04 - categorical_accuracy: 0.2694
# Epoch 170/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.1524e-04 - categorical_accuracy: 0.2684
# Epoch 171/250
# 344/344 [==============================] - 251s 729ms/step - loss: 1.0804e-04 - categorical_accuracy: 0.2902
# Epoch 172/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.0660e-04 - categorical_accuracy: 0.2879
# Epoch 173/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0730e-04 - categorical_accuracy: 0.2987
# Epoch 174/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.1409e-04 - categorical_accuracy: 0.2810
# Epoch 175/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.0576e-04 - categorical_accuracy: 0.3013
# Epoch 176/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0560e-04 - categorical_accuracy: 0.2965
# Epoch 177/250
# 344/344 [==============================] - 252s 732ms/step - loss: 1.0704e-04 - categorical_accuracy: 0.3042
# Epoch 178/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.1100e-04 - categorical_accuracy: 0.2947
# Epoch 179/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0407e-04 - categorical_accuracy: 0.3073
# Epoch 180/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.0226e-04 - categorical_accuracy: 0.3204
# Epoch 181/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.0396e-04 - categorical_accuracy: 0.3173
# Epoch 182/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.0374e-04 - categorical_accuracy: 0.3167
# Epoch 183/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0188e-04 - categorical_accuracy: 0.3208
# Epoch 184/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0348e-04 - categorical_accuracy: 0.3132
# Epoch 185/250
# 344/344 [==============================] - 249s 725ms/step - loss: 1.0720e-04 - categorical_accuracy: 0.3176
# Epoch 186/250
# 344/344 [==============================] - 250s 726ms/step - loss: 1.0389e-04 - categorical_accuracy: 0.3173
# Epoch 187/250
# 344/344 [==============================] - 250s 728ms/step - loss: 1.0321e-04 - categorical_accuracy: 0.3281
# Epoch 188/250
# 344/344 [==============================] - 251s 731ms/step - loss: 1.0537e-04 - categorical_accuracy: 0.3284
# Epoch 189/250
# 344/344 [==============================] - 251s 730ms/step - loss: 1.0278e-04 - categorical_accuracy: 0.3281
# Epoch 190/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.0487e-04 - categorical_accuracy: 0.3254
# Epoch 191/250
# 344/344 [==============================] - 249s 724ms/step - loss: 1.0143e-04 - categorical_accuracy: 0.3443
# Epoch 192/250
# 344/344 [==============================] - 250s 727ms/step - loss: 1.0337e-04 - categorical_accuracy: 0.3437
# Epoch 193/250
# 344/344 [==============================] - 251s 729ms/step - loss: 9.9129e-05 - categorical_accuracy: 0.3453
# Epoch 194/250
# 344/344 [==============================] - 251s 729ms/step - loss: 9.9468e-05 - categorical_accuracy: 0.3495
# Epoch 195/250
# 344/344 [==============================] - 250s 727ms/step - loss: 9.8298e-05 - categorical_accuracy: 0.3509
# Epoch 196/250
# 344/344 [==============================] - 250s 728ms/step - loss: 9.5252e-05 - categorical_accuracy: 0.3627
# Epoch 197/250
# 344/344 [==============================] - 250s 726ms/step - loss: 9.7505e-05 - categorical_accuracy: 0.3517
# Epoch 198/250
# 344/344 [==============================] - 250s 727ms/step - loss: 9.5391e-05 - categorical_accuracy: 0.3654
# Epoch 199/250
# 344/344 [==============================] - 250s 727ms/step - loss: 9.4715e-05 - categorical_accuracy: 0.3735
# Epoch 200/250
# 344/344 [==============================] - 250s 727ms/step - loss: 9.3893e-05 - categorical_accuracy: 0.3773
# Epoch 201/250
# 344/344 [==============================] - 250s 728ms/step - loss: 9.5503e-05 - categorical_accuracy: 0.3677
# Epoch 202/250
# 344/344 [==============================] - 251s 728ms/step - loss: 9.7254e-05 - categorical_accuracy: 0.3707
# Epoch 203/250
# 344/344 [==============================] - 250s 726ms/step - loss: 9.7086e-05 - categorical_accuracy: 0.3739
# Epoch 204/250
# 344/344 [==============================] - 250s 728ms/step - loss: 9.6228e-05 - categorical_accuracy: 0.3835
# Epoch 205/250
# 344/344 [==============================] - 252s 731ms/step - loss: 9.3822e-05 - categorical_accuracy: 0.3930
# Epoch 206/250
# 344/344 [==============================] - 254s 737ms/step - loss: 9.7640e-05 - categorical_accuracy: 0.3772
# Epoch 207/250
# 344/344 [==============================] - 253s 737ms/step - loss: 9.4416e-05 - categorical_accuracy: 0.3967
# Epoch 208/250
# 344/344 [==============================] - 253s 734ms/step - loss: 9.6406e-05 - categorical_accuracy: 0.3918
# Epoch 209/250
# 344/344 [==============================] - 253s 736ms/step - loss: 9.1371e-05 - categorical_accuracy: 0.3953
# Epoch 210/250
# 344/344 [==============================] - 254s 738ms/step - loss: 9.7866e-05 - categorical_accuracy: 0.3871
# Epoch 211/250
# 344/344 [==============================] - 251s 728ms/step - loss: 8.9065e-05 - categorical_accuracy: 0.4105
# Epoch 212/250
# 344/344 [==============================] - 249s 725ms/step - loss: 9.0112e-05 - categorical_accuracy: 0.4026
# Epoch 213/250
# 344/344 [==============================] - 249s 725ms/step - loss: 9.0666e-05 - categorical_accuracy: 0.4125
# Epoch 214/250
# 344/344 [==============================] - 249s 725ms/step - loss: 9.3506e-05 - categorical_accuracy: 0.4031
# Epoch 215/250
# 344/344 [==============================] - 249s 723ms/step - loss: 8.6684e-05 - categorical_accuracy: 0.4226
# Epoch 216/250
# 344/344 [==============================] - 249s 725ms/step - loss: 9.2398e-05 - categorical_accuracy: 0.4040
# Epoch 217/250
# 344/344 [==============================] - 249s 723ms/step - loss: 9.2221e-05 - categorical_accuracy: 0.4161
# Epoch 218/250
# 344/344 [==============================] - 249s 722ms/step - loss: 8.9564e-05 - categorical_accuracy: 0.4251
# Epoch 219/250
# 344/344 [==============================] - 249s 725ms/step - loss: 8.7440e-05 - categorical_accuracy: 0.4197
# Epoch 220/250
# 344/344 [==============================] - 248s 722ms/step - loss: 9.3350e-05 - categorical_accuracy: 0.4159
# Epoch 221/250
# 344/344 [==============================] - 249s 722ms/step - loss: 8.8175e-05 - categorical_accuracy: 0.4186
# Epoch 222/250
# 344/344 [==============================] - 248s 721ms/step - loss: 8.8376e-05 - categorical_accuracy: 0.4244
# Epoch 223/250
# 344/344 [==============================] - 249s 723ms/step - loss: 8.9694e-05 - categorical_accuracy: 0.4285
# Epoch 224/250
# 344/344 [==============================] - 249s 723ms/step - loss: 9.1380e-05 - categorical_accuracy: 0.4300
# Epoch 225/250
# 344/344 [==============================] - 247s 719ms/step - loss: 8.8827e-05 - categorical_accuracy: 0.4303
# Epoch 226/250
# 344/344 [==============================] - 248s 720ms/step - loss: 8.7561e-05 - categorical_accuracy: 0.4281
# Epoch 227/250
# 344/344 [==============================] - 247s 718ms/step - loss: 8.6258e-05 - categorical_accuracy: 0.4397
# Epoch 228/250
# 344/344 [==============================] - 247s 718ms/step - loss: 8.4420e-05 - categorical_accuracy: 0.4480
# Epoch 229/250
# 344/344 [==============================] - 247s 718ms/step - loss: 8.4976e-05 - categorical_accuracy: 0.4494
# Epoch 230/250
# 344/344 [==============================] - 248s 720ms/step - loss: 8.6686e-05 - categorical_accuracy: 0.4390
# Epoch 231/250
# 344/344 [==============================] - 247s 719ms/step - loss: 8.6219e-05 - categorical_accuracy: 0.4477
# Epoch 232/250
# 344/344 [==============================] - 247s 718ms/step - loss: 8.6381e-05 - categorical_accuracy: 0.4475
# Epoch 233/250
# 344/344 [==============================] - 249s 724ms/step - loss: 8.3874e-05 - categorical_accuracy: 0.4615
# Epoch 234/250
# 344/344 [==============================] - 248s 722ms/step - loss: 8.5459e-05 - categorical_accuracy: 0.4611
# Epoch 235/250
# 344/344 [==============================] - 248s 720ms/step - loss: 8.5436e-05 - categorical_accuracy: 0.4480
# Epoch 236/250
# 344/344 [==============================] - 248s 720ms/step - loss: 8.4341e-05 - categorical_accuracy: 0.4622
# Epoch 237/250
# 344/344 [==============================] - 247s 717ms/step - loss: 8.8278e-05 - categorical_accuracy: 0.4498
# Epoch 238/250
# 344/344 [==============================] - 246s 716ms/step - loss: 8.3731e-05 - categorical_accuracy: 0.4644
# Epoch 239/250
# 344/344 [==============================] - 245s 712ms/step - loss: 8.2596e-05 - categorical_accuracy: 0.4743
# Epoch 240/250
# 344/344 [==============================] - 245s 711ms/step - loss: 8.3001e-05 - categorical_accuracy: 0.4710
# Epoch 241/250
# 344/344 [==============================] - 243s 707ms/step - loss: 8.0789e-05 - categorical_accuracy: 0.4832
# Epoch 242/250
# 344/344 [==============================] - 244s 709ms/step - loss: 8.3523e-05 - categorical_accuracy: 0.4779
# Epoch 243/250
# 344/344 [==============================] - 244s 709ms/step - loss: 7.9792e-05 - categorical_accuracy: 0.4805
# Epoch 244/250
# 344/344 [==============================] - 243s 707ms/step - loss: 7.9414e-05 - categorical_accuracy: 0.4881
# Epoch 245/250
# 344/344 [==============================] - 243s 708ms/step - loss: 8.3412e-05 - categorical_accuracy: 0.4851
# Epoch 246/250
# 344/344 [==============================] - 244s 709ms/step - loss: 8.1782e-05 - categorical_accuracy: 0.4850
# Epoch 247/250
# 344/344 [==============================] - 244s 709ms/step - loss: 8.0657e-05 - categorical_accuracy: 0.4822
# Epoch 248/250
# 344/344 [==============================] - 243s 707ms/step - loss: 8.3423e-05 - categorical_accuracy: 0.4863
# Epoch 249/250
# 344/344 [==============================] - 243s 707ms/step - loss: 7.9576e-05 - categorical_accuracy: 0.4949
# Epoch 250/250
# 344/344 [==============================] - 245s 711ms/step - loss: 7.9015e-05 - categorical_accuracy: 0.4932

# %%
# model.save("[0121]svg_momemtum_0.8.h5")
model.save('[0124]RMSprop_0.01.h5')

# %%
model.save('/content/drive/MyDrive/명륜이네 서재/DL_FINAL/model2/[0124]RMSprop_0.01.h5')
